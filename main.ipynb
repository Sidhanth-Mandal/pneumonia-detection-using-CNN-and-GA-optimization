# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import numpy as np
import os
import random
import json
from datetime import datetime
from genetic_algo import GeneticAlgorithm
from training_and_evaluation import train_model , evaluate
from augmentation import get_transforms
from Dataset import PneumoniaDataset

# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def main():
    """Main execution function"""
    
    # Configuration
    DATA_PATH = 'chest_xray'  # Update with your data path
    POPULATION_SIZE = 8
    GENERATIONS = 3
    EPOCHS_PER_INDIVIDUAL = 5
    FINAL_TRAINING_EPOCHS = 20
    
    # Check if data path exists
    if not os.path.exists(DATA_PATH):
        print(f"Error: Data path '{DATA_PATH}' not found!")
        print("Please download the Chest X-Ray dataset from:")
        print("https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia")
        print("\nExpected structure:")
        print("chest_xray/")
        print("  ├── train/")
        print("  │   ├── NORMAL/")
        print("  │   └── PNEUMONIA/")
        print("  ├── val/")
        print("  │   ├── NORMAL/")
        print("  │   └── PNEUMONIA/")
        print("  └── test/")
        print("      ├── NORMAL/")
        print("      └── PNEUMONIA/")
        return
    
    # Run genetic algorithm
    ga = GeneticAlgorithm(
        data_path=DATA_PATH,
        population_size=POPULATION_SIZE,
        generations=GENERATIONS,
        epochs_per_individual=EPOCHS_PER_INDIVIDUAL
    )
    
    best_hyperparams, best_fitness = ga.evolve()
    
    # Save optimization history
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    history_file = f'ga_history_{timestamp}.json'
    with open(history_file, 'w') as f:
        json.dump({
            'best_hyperparameters': best_hyperparams,
            'best_fitness': best_fitness,
            'history': ga.history
        }, f, indent=2)
    print(f"Optimization history saved to {history_file}")
    
    # Train final model with best hyperparameters
    print(f"\n{'='*80}")
    print("Training Final Model with Best Hyperparameters")
    print(f"{'='*80}\n")
    
    final_model, val_acc, f1 = train_model(best_hyperparams, DATA_PATH, 
                                          epochs=FINAL_TRAINING_EPOCHS)
    
    # Evaluate on test set
    _, test_transform = get_transforms(best_hyperparams['augmentation'])
    test_dataset = PneumoniaDataset(DATA_PATH, 'test', transform=test_transform)
    test_loader = DataLoader(test_dataset, batch_size=best_hyperparams['batch_size'],
                           shuffle=False, num_workers=2)
    
    criterion = nn.CrossEntropyLoss()
    test_loss, test_acc, test_precision, test_recall, test_f1 = \
        evaluate(final_model, test_loader, criterion, device)
    
    print(f"\n{'='*80}")
    print("Final Test Results:")
    print(f"  Test Accuracy: {test_acc:.2f}%")
    print(f"  Test Precision: {test_precision:.4f}")
    print(f"  Test Recall: {test_recall:.4f}")
    print(f"  Test F1 Score: {test_f1:.4f}")
    print(f"{'='*80}\n")
    
    # Save final model
    model_file = f'pneumonia_cnn_best_{timestamp}.pth'
    torch.save({
        'model_state_dict': final_model.state_dict(),
        'hyperparameters': best_hyperparams,
        'test_accuracy': test_acc,
        'test_f1': test_f1
    }, model_file)
    print(f"Final model saved to {model_file}")


if __name__ == '__main__':
    main()
# Out:
# ================================================================================
# Starting Genetic Algorithm Optimization
# Population Size: 8, Generations: 3
# ================================================================================
#
#
# ================================================================================
# Generation 1/3
# ================================================================================
#
# Evaluating individual:
#   LR: 0.003752, Batch: 64, Filters: 16, Dropout: 0.670
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 1.2927, Train Acc: 73.26% | Val Loss: 1.4641, Val Acc: 50.00%, F1: 0.6667
# Epoch 2/5: Train Loss: 0.3587, Train Acc: 82.75% | Val Loss: 1.0484, Val Acc: 62.50%, F1: 0.7273
# Epoch 3/5: Train Loss: 0.3537, Train Acc: 84.68% | Val Loss: 0.8148, Val Acc: 62.50%, F1: 0.7273
# Epoch 4/5: Train Loss: 0.3182, Train Acc: 87.10% | Val Loss: 2.0656, Val Acc: 50.00%, F1: 0.6667
# Epoch 5/5: Train Loss: 0.3197, Train Acc: 87.27% | Val Loss: 1.6258, Val Acc: 56.25%, F1: 0.6957
#   Fitness: 64.62 (Val Acc: 62.50%, F1: 0.6957)
#
# Evaluating individual:
#   LR: 0.005991, Batch: 16, Filters: 64, Dropout: 0.194
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 2.5126, Train Acc: 77.82% | Val Loss: 0.8600, Val Acc: 50.00%, F1: 0.6667
# Epoch 2/5: Train Loss: 0.3108, Train Acc: 88.80% | Val Loss: 0.4583, Val Acc: 81.25%, F1: 0.8235
# Epoch 3/5: Train Loss: 0.3387, Train Acc: 86.25% | Val Loss: 0.6249, Val Acc: 50.00%, F1: 0.6667
# Epoch 4/5: Train Loss: 0.3933, Train Acc: 83.65% | Val Loss: 0.7755, Val Acc: 75.00%, F1: 0.8000
# Epoch 5/5: Train Loss: 0.5461, Train Acc: 74.75% | Val Loss: 1.4003, Val Acc: 56.25%, F1: 0.6316
#   Fitness: 75.82 (Val Acc: 81.25%, F1: 0.6316)
#
# Evaluating individual:
#   LR: 0.000590, Batch: 16, Filters: 16, Dropout: 0.620
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.4380, Train Acc: 85.05% | Val Loss: 0.9310, Val Acc: 68.75%, F1: 0.7619
# Epoch 2/5: Train Loss: 0.2125, Train Acc: 91.78% | Val Loss: 0.4523, Val Acc: 81.25%, F1: 0.8421
# Epoch 3/5: Train Loss: 0.1686, Train Acc: 93.58% | Val Loss: 0.3536, Val Acc: 81.25%, F1: 0.8421
# Epoch 4/5: Train Loss: 0.1493, Train Acc: 94.65% | Val Loss: 0.6342, Val Acc: 75.00%, F1: 0.8000
# Epoch 5/5: Train Loss: 0.1352, Train Acc: 95.15% | Val Loss: 0.3651, Val Acc: 75.00%, F1: 0.8000
#   Fitness: 80.88 (Val Acc: 81.25%, F1: 0.8000)
#
# Evaluating individual:
#   LR: 0.007084, Batch: 64, Filters: 64, Dropout: 0.112
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 13.2255, Train Acc: 67.89% | Val Loss: 1.2645, Val Acc: 50.00%, F1: 0.6667
# Epoch 2/5: Train Loss: 0.4212, Train Acc: 74.31% | Val Loss: 0.9931, Val Acc: 50.00%, F1: 0.6667
# Epoch 3/5: Train Loss: 0.3795, Train Acc: 82.42% | Val Loss: 1.2223, Val Acc: 62.50%, F1: 0.7273
# Epoch 4/5: Train Loss: 0.2952, Train Acc: 87.90% | Val Loss: 0.7755, Val Acc: 75.00%, F1: 0.7500
# Epoch 5/5: Train Loss: 0.2554, Train Acc: 90.62% | Val Loss: 0.6887, Val Acc: 68.75%, F1: 0.7619
#   Fitness: 75.36 (Val Acc: 75.00%, F1: 0.7619)
#
# Evaluating individual:
#   LR: 0.008326, Batch: 16, Filters: 16, Dropout: 0.227
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 1.6733, Train Acc: 72.45% | Val Loss: 0.7122, Val Acc: 50.00%, F1: 0.6667
# Epoch 2/5: Train Loss: 0.5318, Train Acc: 76.02% | Val Loss: 1.0099, Val Acc: 50.00%, F1: 0.6667
# Epoch 3/5: Train Loss: 0.5543, Train Acc: 74.46% | Val Loss: 0.7722, Val Acc: 50.00%, F1: 0.6667
# Epoch 4/5: Train Loss: 0.5851, Train Acc: 74.08% | Val Loss: 0.8280, Val Acc: 50.00%, F1: 0.6667
# Epoch 5/5: Train Loss: 0.5522, Train Acc: 75.61% | Val Loss: 0.6461, Val Acc: 56.25%, F1: 0.6667
#   Fitness: 59.38 (Val Acc: 56.25%, F1: 0.6667)
#
# Evaluating individual:
#   LR: 0.001842, Batch: 16, Filters: 32, Dropout: 0.283
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.5114, Train Acc: 88.55% | Val Loss: 0.7491, Val Acc: 81.25%, F1: 0.8421
# Epoch 2/5: Train Loss: 0.1857, Train Acc: 93.31% | Val Loss: 0.2625, Val Acc: 81.25%, F1: 0.8000
# Epoch 3/5: Train Loss: 0.1793, Train Acc: 94.13% | Val Loss: 0.3294, Val Acc: 87.50%, F1: 0.8571
# Epoch 4/5: Train Loss: 0.1751, Train Acc: 93.65% | Val Loss: 0.2652, Val Acc: 87.50%, F1: 0.8889
# Epoch 5/5: Train Loss: 0.1808, Train Acc: 93.75% | Val Loss: 0.2841, Val Acc: 87.50%, F1: 0.8889
#   Fitness: 87.92 (Val Acc: 87.50%, F1: 0.8889)
#
# Evaluating individual:
#   LR: 0.004325, Batch: 32, Filters: 32, Dropout: 0.275
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 2.2140, Train Acc: 75.88% | Val Loss: 0.4468, Val Acc: 93.75%, F1: 0.9412
# Epoch 2/5: Train Loss: 0.2722, Train Acc: 88.77% | Val Loss: 0.3537, Val Acc: 75.00%, F1: 0.7500
# Epoch 3/5: Train Loss: 0.2002, Train Acc: 92.85% | Val Loss: 0.2319, Val Acc: 87.50%, F1: 0.8750
# Epoch 4/5: Train Loss: 0.2247, Train Acc: 91.83% | Val Loss: 0.2691, Val Acc: 87.50%, F1: 0.8750
# Epoch 5/5: Train Loss: 0.2116, Train Acc: 92.27% | Val Loss: 0.7335, Val Acc: 75.00%, F1: 0.8000
#   Fitness: 89.62 (Val Acc: 93.75%, F1: 0.8000)
#
# Evaluating individual:
#   LR: 0.001404, Batch: 32, Filters: 16, Dropout: 0.275
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.4679, Train Acc: 84.13% | Val Loss: 0.6414, Val Acc: 62.50%, F1: 0.7000
# Epoch 2/5: Train Loss: 0.2080, Train Acc: 91.56% | Val Loss: 1.4296, Val Acc: 56.25%, F1: 0.6957
# Epoch 3/5: Train Loss: 0.1465, Train Acc: 95.03% | Val Loss: 1.3150, Val Acc: 50.00%, F1: 0.6667
# Epoch 4/5: Train Loss: 0.1445, Train Acc: 94.88% | Val Loss: 1.6473, Val Acc: 56.25%, F1: 0.6957
# Epoch 5/5: Train Loss: 0.1178, Train Acc: 95.84% | Val Loss: 0.4549, Val Acc: 75.00%, F1: 0.7500
#   Fitness: 75.00 (Val Acc: 75.00%, F1: 0.7500)
#
# Generation 1 Summary:
#   Best Fitness: 89.62
#   Avg Fitness: 76.07
#   Std Fitness: 9.74
#
# ================================================================================
# Generation 2/3
# ================================================================================
#
# Evaluating individual:
#   LR: 0.004325, Batch: 32, Filters: 32, Dropout: 0.275
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 1.1441, Train Acc: 85.79% | Val Loss: 0.2298, Val Acc: 93.75%, F1: 0.9412
# Epoch 2/5: Train Loss: 0.1947, Train Acc: 92.71% | Val Loss: 0.3153, Val Acc: 81.25%, F1: 0.8235
# Epoch 3/5: Train Loss: 0.1989, Train Acc: 93.60% | Val Loss: 0.3991, Val Acc: 75.00%, F1: 0.8000
# Epoch 4/5: Train Loss: 0.2155, Train Acc: 92.56% | Val Loss: 0.4380, Val Acc: 68.75%, F1: 0.7368
# Epoch 5/5: Train Loss: 0.1833, Train Acc: 93.54% | Val Loss: 0.5125, Val Acc: 75.00%, F1: 0.8000
#   Fitness: 89.62 (Val Acc: 93.75%, F1: 0.8000)
#
# Evaluating individual:
#   LR: 0.001842, Batch: 16, Filters: 32, Dropout: 0.194
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.5375, Train Acc: 89.11% | Val Loss: 0.3694, Val Acc: 87.50%, F1: 0.8889
# Epoch 2/5: Train Loss: 0.1748, Train Acc: 93.52% | Val Loss: 0.2004, Val Acc: 87.50%, F1: 0.8750
# Epoch 3/5: Train Loss: 0.1583, Train Acc: 94.50% | Val Loss: 0.4940, Val Acc: 81.25%, F1: 0.8421
# Epoch 4/5: Train Loss: 0.1300, Train Acc: 95.46% | Val Loss: 0.4785, Val Acc: 81.25%, F1: 0.8421
# Epoch 5/5: Train Loss: 0.1620, Train Acc: 94.29% | Val Loss: 0.6509, Val Acc: 68.75%, F1: 0.7619
#   Fitness: 84.11 (Val Acc: 87.50%, F1: 0.7619)
#
# Evaluating individual:
#   LR: 0.004566, Batch: 16, Filters: 64, Dropout: 0.283
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 1.6320, Train Acc: 82.02% | Val Loss: 0.4276, Val Acc: 81.25%, F1: 0.8235
# Epoch 2/5: Train Loss: 0.3060, Train Acc: 87.88% | Val Loss: 0.4400, Val Acc: 75.00%, F1: 0.7143
# Epoch 3/5: Train Loss: 0.3905, Train Acc: 82.99% | Val Loss: 0.4291, Val Acc: 75.00%, F1: 0.7778
# Epoch 4/5: Train Loss: 0.4208, Train Acc: 79.16% | Val Loss: 1.0746, Val Acc: 50.00%, F1: 0.6667
# Epoch 5/5: Train Loss: 0.5232, Train Acc: 73.93% | Val Loss: 0.5770, Val Acc: 50.00%, F1: 0.6667
#   Fitness: 76.87 (Val Acc: 81.25%, F1: 0.6667)
#
# Evaluating individual:
#   LR: 0.007854, Batch: 16, Filters: 16, Dropout: 0.220
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 1.0641, Train Acc: 76.15% | Val Loss: 0.7068, Val Acc: 68.75%, F1: 0.7619
# Epoch 2/5: Train Loss: 0.3640, Train Acc: 84.87% | Val Loss: 0.5345, Val Acc: 62.50%, F1: 0.7000
# Epoch 3/5: Train Loss: 0.4153, Train Acc: 81.83% | Val Loss: 0.3363, Val Acc: 81.25%, F1: 0.8235
# Epoch 4/5: Train Loss: 0.3874, Train Acc: 84.78% | Val Loss: 0.3862, Val Acc: 62.50%, F1: 0.6667
# Epoch 5/5: Train Loss: 0.2074, Train Acc: 92.10% | Val Loss: 2.1358, Val Acc: 62.50%, F1: 0.7273
#   Fitness: 78.69 (Val Acc: 81.25%, F1: 0.7273)
#
# Evaluating individual:
#   LR: 0.000590, Batch: 64, Filters: 64, Dropout: 0.194
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.6949, Train Acc: 82.92% | Val Loss: 2.7092, Val Acc: 50.00%, F1: 0.6667
# Epoch 2/5: Train Loss: 0.1828, Train Acc: 92.83% | Val Loss: 1.4187, Val Acc: 56.25%, F1: 0.6957
# Epoch 3/5: Train Loss: 0.1244, Train Acc: 95.28% | Val Loss: 1.6529, Val Acc: 62.50%, F1: 0.7273
# Epoch 4/5: Train Loss: 0.1174, Train Acc: 95.71% | Val Loss: 2.7028, Val Acc: 50.00%, F1: 0.6667
# Epoch 5/5: Train Loss: 0.1120, Train Acc: 96.03% | Val Loss: 1.0928, Val Acc: 56.25%, F1: 0.6957
#   Fitness: 64.62 (Val Acc: 62.50%, F1: 0.6957)
#
# Evaluating individual:
#   LR: 0.000590, Batch: 16, Filters: 16, Dropout: 0.620
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.4575, Train Acc: 86.00% | Val Loss: 1.1629, Val Acc: 68.75%, F1: 0.7619
# Epoch 2/5: Train Loss: 0.1632, Train Acc: 94.00% | Val Loss: 0.4967, Val Acc: 81.25%, F1: 0.8421
# Epoch 3/5: Train Loss: 0.1307, Train Acc: 95.19% | Val Loss: 0.5188, Val Acc: 87.50%, F1: 0.8889
# Epoch 4/5: Train Loss: 0.1240, Train Acc: 95.51% | Val Loss: 0.4630, Val Acc: 87.50%, F1: 0.8889
# Epoch 5/5: Train Loss: 0.1292, Train Acc: 95.69% | Val Loss: 0.4949, Val Acc: 81.25%, F1: 0.8421
#   Fitness: 86.51 (Val Acc: 87.50%, F1: 0.8421)
#
# Evaluating individual:
#   LR: 0.005147, Batch: 32, Filters: 32, Dropout: 0.283
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 1.4191, Train Acc: 78.72% | Val Loss: 0.6853, Val Acc: 56.25%, F1: 0.6957
# Epoch 2/5: Train Loss: 0.3162, Train Acc: 87.60% | Val Loss: 1.6205, Val Acc: 56.25%, F1: 0.6957
# Epoch 3/5: Train Loss: 0.2780, Train Acc: 89.09% | Val Loss: 0.5720, Val Acc: 75.00%, F1: 0.7778
# Epoch 4/5: Train Loss: 0.3560, Train Acc: 87.14% | Val Loss: 1.9438, Val Acc: 68.75%, F1: 0.7619
# Epoch 5/5: Train Loss: 0.2934, Train Acc: 88.61% | Val Loss: 0.9368, Val Acc: 62.50%, F1: 0.7273
#   Fitness: 74.32 (Val Acc: 75.00%, F1: 0.7273)
#
# Evaluating individual:
#   LR: 0.005991, Batch: 16, Filters: 16, Dropout: 0.194
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.6202, Train Acc: 87.88% | Val Loss: 0.6679, Val Acc: 75.00%, F1: 0.8000
# Epoch 2/5: Train Loss: 0.2364, Train Acc: 91.70% | Val Loss: 0.6406, Val Acc: 62.50%, F1: 0.7273
# Epoch 3/5: Train Loss: 0.1807, Train Acc: 93.58% | Val Loss: 0.2642, Val Acc: 87.50%, F1: 0.8750
# Epoch 4/5: Train Loss: 0.1608, Train Acc: 94.65% | Val Loss: 1.8712, Val Acc: 56.25%, F1: 0.6957
# Epoch 5/5: Train Loss: 0.1775, Train Acc: 93.77% | Val Loss: 0.4917, Val Acc: 87.50%, F1: 0.8889
#   Fitness: 87.92 (Val Acc: 87.50%, F1: 0.8889)
#
# Generation 2 Summary:
#   Best Fitness: 89.62
#   Avg Fitness: 80.33
#   Std Fitness: 7.86
#
# ================================================================================
# Generation 3/3
# ================================================================================
#
# Evaluating individual:
#   LR: 0.004325, Batch: 32, Filters: 32, Dropout: 0.275
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 1.3707, Train Acc: 75.48% | Val Loss: 0.6246, Val Acc: 56.25%, F1: 0.2222
# Epoch 2/5: Train Loss: 0.2695, Train Acc: 89.23% | Val Loss: 2.1397, Val Acc: 62.50%, F1: 0.7273
# Epoch 3/5: Train Loss: 0.2222, Train Acc: 91.87% | Val Loss: 0.4666, Val Acc: 75.00%, F1: 0.6667
# Epoch 4/5: Train Loss: 0.2150, Train Acc: 92.68% | Val Loss: 0.9407, Val Acc: 68.75%, F1: 0.7619
# Epoch 5/5: Train Loss: 0.1847, Train Acc: 92.91% | Val Loss: 4.5115, Val Acc: 62.50%, F1: 0.7273
#   Fitness: 74.32 (Val Acc: 75.00%, F1: 0.7273)
#
# Evaluating individual:
#   LR: 0.005928, Batch: 16, Filters: 64, Dropout: 0.128
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 1.8609, Train Acc: 72.85% | Val Loss: 0.8293, Val Acc: 50.00%, F1: 0.6667
# Epoch 2/5: Train Loss: 0.5790, Train Acc: 74.00% | Val Loss: 0.8303, Val Acc: 50.00%, F1: 0.6667
# Epoch 3/5: Train Loss: 0.5696, Train Acc: 74.23% | Val Loss: 0.8696, Val Acc: 50.00%, F1: 0.6667
# Epoch 4/5: Train Loss: 0.6254, Train Acc: 73.73% | Val Loss: 0.8401, Val Acc: 50.00%, F1: 0.6667
# Epoch 5/5: Train Loss: 0.6855, Train Acc: 74.10% | Val Loss: 0.7885, Val Acc: 50.00%, F1: 0.6667
#   Fitness: 55.00 (Val Acc: 50.00%, F1: 0.6667)
#
# Evaluating individual:
#   LR: 0.006079, Batch: 16, Filters: 32, Dropout: 0.620
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 3.0113, Train Acc: 71.43% | Val Loss: 0.8266, Val Acc: 50.00%, F1: 0.6667
# Epoch 2/5: Train Loss: 0.5987, Train Acc: 73.70% | Val Loss: 0.8457, Val Acc: 50.00%, F1: 0.6667
# Epoch 3/5: Train Loss: 0.6540, Train Acc: 73.24% | Val Loss: 0.8302, Val Acc: 50.00%, F1: 0.6667
# Epoch 4/5: Train Loss: 0.5939, Train Acc: 73.93% | Val Loss: 0.7932, Val Acc: 50.00%, F1: 0.6667
# Epoch 5/5: Train Loss: 0.5848, Train Acc: 74.06% | Val Loss: 0.8904, Val Acc: 50.00%, F1: 0.6667
#   Fitness: 55.00 (Val Acc: 50.00%, F1: 0.6667)
#
# Evaluating individual:
#   LR: 0.000590, Batch: 16, Filters: 16, Dropout: 0.202
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.2096, Train Acc: 92.71% | Val Loss: 0.6773, Val Acc: 68.75%, F1: 0.7619
# Epoch 2/5: Train Loss: 0.1048, Train Acc: 96.28% | Val Loss: 1.2513, Val Acc: 62.50%, F1: 0.7273
# Epoch 3/5: Train Loss: 0.0821, Train Acc: 97.07% | Val Loss: 0.9575, Val Acc: 81.25%, F1: 0.8421
# Epoch 4/5: Train Loss: 0.0762, Train Acc: 97.45% | Val Loss: 0.1921, Val Acc: 100.00%, F1: 1.0000
# Epoch 5/5: Train Loss: 0.0781, Train Acc: 96.99% | Val Loss: 0.1585, Val Acc: 100.00%, F1: 1.0000
#   Fitness: 100.00 (Val Acc: 100.00%, F1: 1.0000)
#
# Evaluating individual:
#   LR: 0.000590, Batch: 16, Filters: 16, Dropout: 0.139
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.2519, Train Acc: 91.41% | Val Loss: 0.3711, Val Acc: 87.50%, F1: 0.8889
# Epoch 2/5: Train Loss: 0.1114, Train Acc: 95.57% | Val Loss: 0.9375, Val Acc: 68.75%, F1: 0.7619
# Epoch 3/5: Train Loss: 0.0888, Train Acc: 96.76% | Val Loss: 0.2954, Val Acc: 93.75%, F1: 0.9412
# Epoch 4/5: Train Loss: 0.0806, Train Acc: 97.12% | Val Loss: 0.5015, Val Acc: 81.25%, F1: 0.8421
# Epoch 5/5: Train Loss: 0.0765, Train Acc: 97.24% | Val Loss: 0.5820, Val Acc: 75.00%, F1: 0.8000
#   Fitness: 89.62 (Val Acc: 93.75%, F1: 0.8000)
#
# Evaluating individual:
#   LR: 0.000590, Batch: 16, Filters: 16, Dropout: 0.194
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.1975, Train Acc: 92.56% | Val Loss: 0.2136, Val Acc: 87.50%, F1: 0.8750
# Epoch 2/5: Train Loss: 0.1151, Train Acc: 95.72% | Val Loss: 0.4323, Val Acc: 93.75%, F1: 0.9412
# Epoch 3/5: Train Loss: 0.0932, Train Acc: 96.74% | Val Loss: 1.2452, Val Acc: 68.75%, F1: 0.7619
# Epoch 4/5: Train Loss: 0.0707, Train Acc: 97.18% | Val Loss: 0.1455, Val Acc: 93.75%, F1: 0.9412
# Epoch 5/5: Train Loss: 0.0752, Train Acc: 97.37% | Val Loss: 0.2499, Val Acc: 93.75%, F1: 0.9412
#   Fitness: 93.86 (Val Acc: 93.75%, F1: 0.9412)
#
# Evaluating individual:
#   LR: 0.009657, Batch: 16, Filters: 16, Dropout: 0.620
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 2.2512, Train Acc: 71.05% | Val Loss: 0.8282, Val Acc: 50.00%, F1: 0.6667
# Epoch 2/5: Train Loss: 0.6008, Train Acc: 74.75% | Val Loss: 0.7959, Val Acc: 50.00%, F1: 0.6667
# Epoch 3/5: Train Loss: 0.5780, Train Acc: 75.36% | Val Loss: 0.7567, Val Acc: 56.25%, F1: 0.6957
# Epoch 4/5: Train Loss: 0.4613, Train Acc: 80.14% | Val Loss: 1.1862, Val Acc: 50.00%, F1: 0.6667
# Epoch 5/5: Train Loss: 0.3935, Train Acc: 84.34% | Val Loss: 0.6834, Val Acc: 68.75%, F1: 0.7368
#   Fitness: 70.23 (Val Acc: 68.75%, F1: 0.7368)
#
# Evaluating individual:
#   LR: 0.000590, Batch: 16, Filters: 16, Dropout: 0.620
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/5: Train Loss: 0.4631, Train Acc: 86.22% | Val Loss: 0.4008, Val Acc: 87.50%, F1: 0.8889
# Epoch 2/5: Train Loss: 0.1720, Train Acc: 93.69% | Val Loss: 0.6081, Val Acc: 75.00%, F1: 0.8000
# Epoch 3/5: Train Loss: 0.1385, Train Acc: 95.28% | Val Loss: 0.2344, Val Acc: 87.50%, F1: 0.8889
# Epoch 4/5: Train Loss: 0.1139, Train Acc: 96.11% | Val Loss: 0.2193, Val Acc: 87.50%, F1: 0.8571
# Epoch 5/5: Train Loss: 0.1048, Train Acc: 96.26% | Val Loss: 0.2732, Val Acc: 81.25%, F1: 0.8235
#   Fitness: 85.96 (Val Acc: 87.50%, F1: 0.8235)
#
# Generation 3 Summary:
#   Best Fitness: 100.00
#   Avg Fitness: 78.00
#   Std Fitness: 16.07
#
# ================================================================================
# Optimization Complete!
# Best Fitness: 100.00
# Best Hyperparameters:
# {
#   "learning_rate": 0.0005902552855603126,
#   "batch_size": 16,
#   "num_filters": 16,
#   "dropout_rate": 0.20231447421237492,
#   "weight_decay": 0.0005252316752006056,
#   "augmentation": {
#     "horizontal_flip": true,
#     "rotation": 0,
#     "brightness": 0,
#     "contrast": 0
#   }
# }
# ================================================================================
#
# Optimization history saved to ga_history_20251028_152313.json
#
# ================================================================================
# Training Final Model with Best Hyperparameters
# ================================================================================
#
# train set: 5216 images (3875 pneumonia, 1341 normal)
# val set: 16 images (8 pneumonia, 8 normal)
# Epoch 1/20: Train Loss: 0.2062, Train Acc: 92.45% | Val Loss: 0.4749, Val Acc: 75.00%, F1: 0.8000
# Epoch 2/20: Train Loss: 0.1017, Train Acc: 96.34% | Val Loss: 0.5638, Val Acc: 81.25%, F1: 0.8421
# Epoch 3/20: Train Loss: 0.0808, Train Acc: 97.20% | Val Loss: 0.2322, Val Acc: 93.75%, F1: 0.9412
# Epoch 4/20: Train Loss: 0.0763, Train Acc: 96.97% | Val Loss: 0.2851, Val Acc: 87.50%, F1: 0.8571
# Epoch 5/20: Train Loss: 0.0763, Train Acc: 97.07% | Val Loss: 0.1525, Val Acc: 100.00%, F1: 1.0000
# Epoch 6/20: Train Loss: 0.0666, Train Acc: 97.66% | Val Loss: 0.1043, Val Acc: 100.00%, F1: 1.0000
# Epoch 7/20: Train Loss: 0.0615, Train Acc: 97.80% | Val Loss: 0.1340, Val Acc: 100.00%, F1: 1.0000
# Epoch 8/20: Train Loss: 0.0575, Train Acc: 97.80% | Val Loss: 0.1653, Val Acc: 93.75%, F1: 0.9412
# Epoch 9/20: Train Loss: 0.0565, Train Acc: 97.97% | Val Loss: 0.6073, Val Acc: 62.50%, F1: 0.7273
# Epoch 10/20: Train Loss: 0.0588, Train Acc: 97.74% | Val Loss: 0.2938, Val Acc: 87.50%, F1: 0.8889
# Epoch 11/20: Train Loss: 0.0574, Train Acc: 97.87% | Val Loss: 0.0759, Val Acc: 100.00%, F1: 1.0000
# Epoch 12/20: Train Loss: 0.0541, Train Acc: 98.22% | Val Loss: 0.2571, Val Acc: 81.25%, F1: 0.8421
# Epoch 13/20: Train Loss: 0.0476, Train Acc: 98.33% | Val Loss: 0.0866, Val Acc: 100.00%, F1: 1.0000
# Epoch 14/20: Train Loss: 0.0522, Train Acc: 98.35% | Val Loss: 0.1140, Val Acc: 87.50%, F1: 0.8889
# Epoch 15/20: Train Loss: 0.0514, Train Acc: 98.26% | Val Loss: 0.1690, Val Acc: 93.75%, F1: 0.9412
# Epoch 16/20: Train Loss: 0.0491, Train Acc: 98.45% | Val Loss: 0.2140, Val Acc: 87.50%, F1: 0.8889
# Epoch 17/20: Train Loss: 0.0420, Train Acc: 98.43% | Val Loss: 0.0107, Val Acc: 100.00%, F1: 1.0000
# Epoch 18/20: Train Loss: 0.0434, Train Acc: 98.62% | Val Loss: 1.0357, Val Acc: 62.50%, F1: 0.7273
# Epoch 19/20: Train Loss: 0.0404, Train Acc: 98.58% | Val Loss: 0.0744, Val Acc: 100.00%, F1: 1.0000
# Epoch 20/20: Train Loss: 0.0342, Train Acc: 98.87% | Val Loss: 0.1991, Val Acc: 93.75%, F1: 0.9412
# test set: 624 images (390 pneumonia, 234 normal)
#
# ================================================================================
# Final Test Results:
#   Test Accuracy: 78.21%
#   Test Precision: 0.7520
#   Test Recall: 0.9718
#   Test F1 Score: 0.8479
# ================================================================================
#
# Final model saved to pneumonia_cnn_best_20251028_152313.pth
